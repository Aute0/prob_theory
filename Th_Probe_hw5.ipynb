# %% [markdown]
# <a href="https://colab.research.google.com/github/Aute0/prob_theory/blob/main/Th_Probe_hw5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from statsmodels.stats.weightstats import _tconfint_generic as t_stat
from scipy.stats import norm 
import math

# %% [markdown]
# ### Задача №1
#
# Когда используется критерий Стьюдента, а когда Z –критерий?
#
# - Если известна дисперсия ген. совокупности, то выбираем Z распределение
# - Если не известна дисперсия - критерий Стьюдента
#
# При больших размерах выборок результаты Z- теста и t-теста дают схожие значения p-value

# %% [markdown]
# ### Задача №2
#
# Утверждается, что шарики для подшипников, изготовленные автоматическим станком, имеют средний диаметр 17 мм.
# Используя односторонний критерий с α=0,05, проверить эту гипотезу, если в выборке из n=100 шариков средний диаметр
# оказался равным 17.5 мм, а дисперсия известна и равна 4 мм.

# %% [markdown]
# H0: M = 17 Нулевая гипотеза
#
# H1: M > 17
#
# Zt = 1.645 ( т.к. α=0,05)

# %%
Z_fact = (17.5 - 17) / (2 / np.sqrt(100))

# %%
Z_fact
# Out:
# 2.5

# %% [markdown]
# т.к. U_fact > U_cr Нулевая гипотеза **отвергается**

# %% [markdown]
# ![photo_2023-02-04_23-15-02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Задача №3
#
# Продавец утверждает, что средний вес пачки печенья составляет 200 г.
# Из партии извлечена выборка из 10 пачек. Вес каждой пачки составляет:
# 202, 203, 199, 197, 195, 201, 200, 204, 194, 190.
# Известно, что их веса распределены нормально.
# Верно ли утверждение продавца, если учитывать, что доверительная вероятность равна 99%?

# %% [markdown]
# H0: M = 200
#
# H1: M != 200

# %%
X = np.array([202, 203, 199, 197, 195, 201, 200, 204, 194, 190])
mean_X = X.mean()
std_X = X.std(ddof=1)
std_X
# Out:
# 4.453463071962462

# %%
t_fact = (mean_X - 200) / std_X * np.sqrt(10)
t_fact
# Out:
# -1.0651074037450896

# %%
t_cr = 3.25

# %% [markdown]
# т.к. abs(t_fact) < t_cr нулевая гипотеза принимается

# %% [markdown]
# ![photo_2023-02-04_23-31-35.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Задача №4
#
# Есть ли статистически значимые различия в росте дочерей и матерей?
#
# - Рост матерей 172, 177, 158, 170, 178,175, 164, 160, 169
# - Рост взрослых дочерей: 173, 175, 162, 174, 175, 168, 155, 170, 160

# %% [markdown]
# Будем считать через p_value
#
# p_val >  a - принимаем нулевую гипотезу
#
# p_val < a - отвергаем нулевую, принмаем первую

# %%
hight_ma = np.array([172, 177, 158, 170, 178,175, 164, 160, 169.])
np.mean(hight_ma)
# Out:
# 169.22222222222223

# %%
hight_ma_std = hight_ma.std(ddof=1)
hight_ma_std
# Out:
# 7.22457226723108

# %%
len(hight_ma)
# Out:
# 9

# %%
hight_do = np.array([173, 175, 162, 174, 175, 168, 155, 170, 160.])
np.mean(hight_do)
# Out:
# 168.0

# %%
hight_do_std = hight_do.std(ddof=1)
hight_do_std
# Out:
# 7.3484692283495345

# %%
import scipy.stats as stats
stats.ttest_rel(hight_ma,hight_do)
# Out:
# Ttest_relResult(statistic=0.559522990335608, pvalue=0.5911212354055175)

# %% [markdown]
#     pvalue = 0,559 > α(альфа) = 0,05
#     statistic = 0,591 < табличное значение = 2,306
#
# Вывод:  верна нулевая теория
